// %%
import Line_1_jupyter.___temp_declarations.notificationEventListener
import com.example.sideproject.domain.notification.dto.EventDto
import com.example.sideproject.domain.notification.entity.NotificationType

// notification 통합 테스트
// 준비물: 알림 서버 (PR-Notification)

val eventDto = EventDto.builder()
    .to(2L)
    .from(1L)
    .title("notification test 제목")
    .msg("test 메시지")
    .type(NotificationType.PROJECT_APPLICANT)
    .relatedId(3L)
    .pushAllowed(true)
    .needToPush(true)
    .build()

notificationEventListener?.sendNotification(eventDto)
